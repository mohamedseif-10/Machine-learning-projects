# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori,fpgrowth, association_rules  # type: ignore

# %%
data = pd.read_csv("../Data/Sales.csv", sep=";")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_24152\4175937743.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../Data/Sales.csv", sep=";")

# %%
data = data.iloc[:10000, :]

# %%
data.head()
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom

# %%
data.shape
# Out:
# (10000, 7)

# %%
data = data[['BillNo', 'Itemname']]

# %%
data.isnull().sum()
# Out:
# BillNo       0
# Itemname    42
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9958 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BillNo    9958 non-null   object
#  1   Itemname  9958 non-null   object
# dtypes: object(2)
# memory usage: 233.4+ KB

# %%
data.head(10)
# Out:
#    BillNo                             Itemname
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER
# 1  536365                  WHITE METAL LANTERN
# 2  536365       CREAM CUPID HEARTS COAT HANGER
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.
# 5  536365         SET 7 BABUSHKA NESTING BOXES
# 6  536365    GLASS STAR FROSTED T-LIGHT HOLDER
# 7  536366               HAND WARMER UNION JACK
# 8  536366            HAND WARMER RED POLKA DOT
# 9  536367        ASSORTED COLOUR BIRD ORNAMENT

# %%
transactions = data.groupby("BillNo")["Itemname"].apply(list).reset_index()
transactions.head()
# Out:
#    BillNo                                           Itemname
# 0  536365  [WHITE HANGING HEART T-LIGHT HOLDER, WHITE MET...
# 1  536366  [HAND WARMER UNION JACK, HAND WARMER RED POLKA...
# 2  536367  [ASSORTED COLOUR BIRD ORNAMENT, POPPY'S PLAYHO...
# 3  536368  [JAM MAKING SET WITH JARS, RED COAT RACK PARIS...
# 4  536369                         [BATH BUILDING BLOCK WORD]

# %%
te = TransactionEncoder()
transactions_bool_list = te.fit(transactions["Itemname"]).transform(transactions["Itemname"])


data_transaction = pd.DataFrame(transactions_bool_list, columns=te.columns_)
data_transaction.shape
# Out:
# (430, 1981)

# %%
pd.set_option('display.max_columns', None)
data_transaction.columns
# Out:
# Index(['10 COLOUR SPACEBOY PEN', '12 COLOURED PARTY BALLOONS',
#        '12 DAISY PEGS IN WOOD BOX', '12 IVORY ROSE PEG PLACE SETTINGS',
#        '12 MESSAGE CARDS WITH ENVELOPES', '12 PENCIL SMALL TUBE WOODLAND',
#        '12 PENCILS SMALL TUBE RED RETROSPOT', '12 PENCILS SMALL TUBE SKULL',
#        '12 PENCILS TALL TUBE POSY', '12 PENCILS TALL TUBE RED RETROSPOT',
#        ...
#        'YELLOW/PINK FLOWER DESIGN BIG MUG', 'YOU'RE CONFUSING ME METAL SIGN',
#        'YULETIDE IMAGES GIFT WRAP SET', 'YULETIDE IMAGES S/6 PAPER BOXES',
#        'ZINC FINISH 15CM PLANTER POTS', 'ZINC FOLKART SLEIGH BELLS',
#        'ZINC HEART LATTICE T-LIGHT HOLDER', 'ZINC METAL HEART DECORATION',
#        'ZINC WILLIE WINKIE  CANDLE STICK', 'amazon'],
#       dtype='object', length=1981)

# %% [markdown]
# # Evaluation for apiori

# %%
frequent_itemsets = apriori(data_transaction, min_support=0.05, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0, num_itemsets=100)
rules = rules.sort_values(["confidence", "lift"], ascending=[False, False])

rules[["antecedents", "consequents", "support", "confidence", "lift"]].head(10)
# Out:
#                                           antecedents  \
# 28  (WHITE HANGING HEART T-LIGHT HOLDER, RED WOOLL...
# 26  (KNITTED UNION FLAG HOT WATER BOTTLE, WHITE HA...
# 21  (HAND WARMER SCOTTY DOG DESIGN, HAND WARMER RE...
# 22  (HAND WARMER OWL DESIGN, HAND WARMER RED RETRO...
# 27  (KNITTED UNION FLAG HOT WATER BOTTLE, RED WOOL...
# 12              (KNITTED UNION FLAG HOT WATER BOTTLE)
# 13                   (RED WOOLLY HOTTIE WHITE HEART.)
# 6                     (HAND WARMER SCOTTY DOG DESIGN)
# 5                         (HAND WARMER RED RETROSPOT)
# 7                            (HAND WARMER OWL DESIGN)
#
#                               consequents   support  confidence      lift
# 28  (KNITTED UNION FLAG HOT WATER BOTTLE)  0.053488    0.920000  9.648780
# 26       (RED WOOLLY HOTTIE WHITE HEART.)  0.053488    0.884615  9.056777
# 21               (HAND WARMER OWL DESIGN)  0.051163    0.880000  7.276923
# 22        (HAND WARMER SCOTTY DOG DESIGN)  0.051163    0.814815  7.150416
# 27   (WHITE HANGING HEART T-LIGHT HOLDER)  0.053488    0.766667  5.993939
# 12       (RED WOOLLY HOTTIE WHITE HEART.)  0.069767    0.731707  7.491289
# 13  (KNITTED UNION FLAG HOT WATER BOTTLE)  0.069767    0.714286  7.491289
# 6                (HAND WARMER OWL DESIGN)  0.079070    0.693878  5.737834
# 5                (HAND WARMER OWL DESIGN)  0.062791    0.658537  5.445591
# 7         (HAND WARMER SCOTTY DOG DESIGN)  0.079070    0.653846  5.737834

# %% [markdown]
# # Evaluation FPgrowth

# %%
frequent_itemsets_fp = fpgrowth(data_transaction, min_support=0.05, use_colnames=True)

rules_fp = association_rules(frequent_itemsets_fp, metric="lift", min_threshold=1.0, num_itemsets=100)
rules_fp = rules_fp.sort_values(["confidence", "lift"], ascending=[False, False])

rules_fp[["antecedents", "consequents", "support", "confidence", "lift"]].head(10)
# Out:
#                                           antecedents  \
# 8   (WHITE HANGING HEART T-LIGHT HOLDER, RED WOOLL...
# 6   (KNITTED UNION FLAG HOT WATER BOTTLE, WHITE HA...
# 23  (HAND WARMER SCOTTY DOG DESIGN, HAND WARMER RE...
# 24  (HAND WARMER OWL DESIGN, HAND WARMER RED RETRO...
# 7   (KNITTED UNION FLAG HOT WATER BOTTLE, RED WOOL...
# 2               (KNITTED UNION FLAG HOT WATER BOTTLE)
# 3                    (RED WOOLLY HOTTIE WHITE HEART.)
# 14                    (HAND WARMER SCOTTY DOG DESIGN)
# 19                        (HAND WARMER RED RETROSPOT)
# 15                           (HAND WARMER OWL DESIGN)
#
#                               consequents   support  confidence      lift
# 8   (KNITTED UNION FLAG HOT WATER BOTTLE)  0.053488    0.920000  9.648780
# 6        (RED WOOLLY HOTTIE WHITE HEART.)  0.053488    0.884615  9.056777
# 23               (HAND WARMER OWL DESIGN)  0.051163    0.880000  7.276923
# 24        (HAND WARMER SCOTTY DOG DESIGN)  0.051163    0.814815  7.150416
# 7    (WHITE HANGING HEART T-LIGHT HOLDER)  0.053488    0.766667  5.993939
# 2        (RED WOOLLY HOTTIE WHITE HEART.)  0.069767    0.731707  7.491289
# 3   (KNITTED UNION FLAG HOT WATER BOTTLE)  0.069767    0.714286  7.491289
# 14               (HAND WARMER OWL DESIGN)  0.079070    0.693878  5.737834
# 19               (HAND WARMER OWL DESIGN)  0.062791    0.658537  5.445591
# 15        (HAND WARMER SCOTTY DOG DESIGN)  0.079070    0.653846  5.737834

# %% [markdown]
# # The two algorithms  are efficient and provide the same support - Confidence and left
